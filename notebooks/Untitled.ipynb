# %%
# !pwd
# Out:
# /nfs/cfs/home3/Uucfa6/ucfalew/geog0111/notebooks

# %%
from geog0111.d import *
# Out:
# --> initial SDS ['NDSI_Snow_Cover']
# > /nfs/cfs/home3/Uucfa6/ucfalew/geog0111/notebooks/geog0111/modis.py(92)__init__()
#      90     self.sds = None
#      91     import pdb;pdb.set_trace()
# ---> 92     response = self.database.get_from_db('SDS',self.product)
#      93     if response:
#      94       self.msg("found SDS names in database")
#
# ipdb> S
# *** NameError: name 'S' is not defined
# ipdb> Step
# *** NameError: name 'Step' is not defined
# ipdb> s
# --Call--
# > /nfs/cfs/home3/Uucfa6/ucfalew/geog0111/notebooks/geog0111/database.py(320)get_from_db()
#     318     return self.database
#     319
# --> 320   def get_from_db(self,flag,url):
#     321     '''see if url is in database'''
#     322     url = str(url)
#
# ipdb> s
# > /nfs/cfs/home3/Uucfa6/ucfalew/geog0111/notebooks/geog0111/database.py(322)get_from_db()
#     320   def get_from_db(self,flag,url):
#     321     '''see if url is in database'''
# --> 322     url = str(url)
#     323     try:
# ...

# %%
s  print() n c
