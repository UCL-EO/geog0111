# %% [markdown]
# ### Teaching notes:
#
# Issues with the practical part 2.an as its just a stack of data
# Sigma needs to be 20, not 5
#
# Change the regularisation notes to reflect the need to experiment with sigma:
#
# Want a minimum sigma for when all pixels are valid. That is the minimumum sigma you should consider.
#
# Demonstrated here:

# %%
from geog0111.get_snow_data import get_snow_data
from geog0111.regularise import regularise

import matplotlib.pyplot as plt

snow,doy = get_snow_data(2019)
weight = (snow <= 100).astype(float)
# Out:
# we dont need to process MOD10A1._h09v05_.2019

# %%
plt.imshow(weight.mean(axis=0))

# %%
plt.imshow(snow.mean(axis=0))

# %%
reg_snow = regularise(snow,weight,5.0)
plt.imshow(reg_snow.mean(axis=0))

# %%
reg_snow = regularise(snow,weight,10.0)
plt.imshow(reg_snow.mean(axis=0))

# %%
reg_snow = regularise(snow,weight,20.0)
plt.imshow(reg_snow.mean(axis=0))
